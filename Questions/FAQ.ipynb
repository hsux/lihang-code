# %% [markdown]
# # ML相关

# %% [markdown]
# 1. gbdt 的基本原理，gbdt+lr的过程？
#
# 2. lr的基本原理，为什么要用sigmoid的函数，最大熵模型是否了解过？
#
# 3. svm的基本原理，对偶问题的作用，写出公式？
#
# 4. 数据分析，特征构建，特征选择，模型调参，上线部署到监控？
#
# 5. 怎么对模型效果进行评估的？发现模型性能下降有什么改进方法，从模型角度、数据角度分析？
#
# 6. gbdt 、xgboost 、rf三者的不同？
#
# 7. gbdt的梯度提升体现在什么地方，在损失函数不是平方损失函数时为什么可以用t-1步分类函数相对于损失函数的负梯度来作为残差的近似值，数学意义？
#
# 8. gbdt中每个弱分类器是什么，为什么用cart回归树而不是分类树，节点的分裂规则，写出公式。公式中的每个值在实际训练过程中是怎么计算出来的，举列子说明？
#
# 9. gbdt的训练过程，做分类预测时候如何训练的，cart回归树的节点分裂过程。对于连续或离散变量，树节点如何划分类别？
#
# 10. gbdt的概率是怎么计算的？gbdt能否计算多分类问题，是互斥多分类问题，还是非互斥多分类？如果要做非互斥多分类，在gbdt哪一步做改进？
#
# 11. gbdt残差是怎么计算的，损失函数的形式？
#
# 12. gbdt调过哪些参数，都什么作用？为什么有这个作用，从原理出发讲一下？
#      - subsample 作用？为什么能提高泛化性能？这里的subsample和rf里的采样是一个作用吗？rf里的行采样、列采样的作用？rf为什么要使得每棵树不一样？gbdt里的subsample和rf不是一个作用
#
#      - Shrinkage作用，为什么设置学习率可以防止过拟合？为什么一般情况下设置学习率模型效果会变好，原理是什么？在gbdt训练过程中，学习率是如何使用的
#
# 13. 不均衡样本训练时有什么方法提高模型性能
#     - 上采样、下采样
#     - easy-enesmble ，几种方式？
#     - scale_pos_weight怎么实现的
#     https://zhuanlan.zhihu.com/p/195735073?utm_source=wechat_session
#     - smote算法原理
#
# 14. AUC 的含义
#
# 15. 分布式 SGD
#
# 16. 正则化方法有哪些？ 追问： L1，L2的数学意义，Dropout原理 ...
#
# 17. Xgb里防止过拟合可以设置的参数
#
# 18. RF 原理讲一下，为什么能防止过拟合
#
# 19. Xgboost原理，对比GBDT的改进。追问：论文里用二次导数的累计值选取切分节点的依据
#
# 20. LightGBM原理，追问：直方图算法的具体实现逻辑（是否看过源码）
#
# 21. 无监督模型
#
#     - 层次聚类原理，时间复杂度。连通性矩阵作用，如何约束？（项目里提到了）
#     - DBScan原理
#     - 聚类评价指标有哪些

# %% [markdown]
# # DL相关

# %% [markdown]
# 1. 是否用过dnn、cnn等方法尝试做模型：
#     - 画出网络结构，激活函数用的什么，relu比sigmoid的好处有哪些
#     - 用的什么优化方法？ 有哪些优化方法，分别说一下，每种优化方法的过程，写出参数更新公式
#     - 为什么要用动量，它比mini-batch好的数学意义是什么。为什么动量可以走出局部最小值，数学解释，不能画图
#     - l1、l2的作用，为什么l1偏向于使特征稀疏，l2偏向每个特征都变小。不能画图，用数学意义解释
#
# 2. BN 的原理，计算方式
#
# 3. LSTM 原理 为什么好于RNN，GRU原理
#
# 4. 激活函数有哪些。追问：实际用过Selu吗，效果怎么样
#
# 5. 深度模型单调性约束要怎么实现，给出两种方案
#
# 6. 强化学习是否了解。追问：DQN的原理，Dueling什么意思
#
# 7. WDL DeepFM DCN DIN DIEN DSTN ... 原理，是否实际用过，为什么能带来提升 ，为什么效果不好（因为简历上写了）

# %% [markdown]
# # 大数据相关

# %% [markdown]
# 1. hive 中数据倾斜是否遇到过？
#
# 2. hadoop是否了解，讲一下基本过程。如果想用Hadoop对海量数字排序，有几种实现方式？
#
# 3. 是否写过map、reduce程序，是否接触过海量数据处理，基本过程？
#
# 4. hive中什么样的操作会启动reduce进程？
#
# 5. 考了一个hive sql ，比较简单，一个join 一个 having？

# %% [markdown]
# # 项目相关

# %% [markdown]
# 1. 聊一个自己感觉最有难度的项目，在项目中做的工作是什么？
#
# 2. 业务中要解决的问题是什么，注重坏用户的召回还是预测的准确率？
#
# 3. 标签怎么定义的，分析过程是什么？包括金融模型中的表现期、坏用户定义都问了一下？
#
# 4. 样本量多少？怎么采样的，是否考虑时间对样本的影响？
#
# 5. 获取特征的时间段是什么？如果一些用户消费都来自比较早的时间，对模型建模是否有影响，怎么解决这种影响？
#
# 6. 如何做的特征筛选？（我回答先删掉自相关特征，然后再用gbdt）追问，为什么删掉自相关特征，直接放入gbdt训练是否可以？
#
# 7. 平时是否有看论文的习惯，说说看过哪些论文？
#
# 8. 主要介绍最好的一个项目：
#     - 项目背景
#     - 目标
#     - 现状
#     - 改进点
#     - 改进方式（模型怎么选，为什么选，怎么优化的，这一步可以说的细一点，突出你自己对业务的理解还有解决实际问题的能力）
#     - 模型效果、业务收益

# %% [markdown]
# # 个人相关

# %% [markdown]
# 1. 对自己的学习能力做评价，在遇到不会的问题时如何解决？
#
# 2. 自我介绍：
#     - 工作年限
#     - 学校
#     - 工作经历（主要方向）
#     - 实习经验
#     - 获奖经历（Kaggle, ACM）等
# 3.

# %% [markdown]
# # 其他

# %% [markdown]
# 1. 项目部分：不会只考察你的执行能力，还会更多关注你对业务的理解、拆分能力。考察你是否可以选择对的模型，对的算法拿到收益。
#
# 2. Coding：Leetcode真的很有用。
#
# 3. ML部分：不会只问你模型原理，会追问你是否看过论文、源码，为什么选择这个模型，会问业务上的评价指标是什么。即使每一个小问题，也可以问的很深。主流算法就那么几个，从各个角度考察你对模型的理解，更能衡量你的能力。
